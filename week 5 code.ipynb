# %% [markdown]
# # Capstone Project - The Battle of the Neighborhoods

# %% [markdown]
# ## Introduction: Business Problem <a name="introduction"></a>

# %% [markdown]
# In this project we are going to find a location in Toronto to open a restaurant. This report will be targeted to stakeholders interested in opening an **Chinese restaurant** in **Toronto**, Canada.
#
# Since Toronto is a well-diversified city, you can find cuisines from all over the world. Toronto has handreds of thousands Chinese people. There are lots of authentic Chinese food in Greater Toronto Area. We are looking for locations where there are few Chinese food and locations near city centre
#
# We are going to use data science to observe neighborhoods that meet our criterias.We will deliver the advantages of each locations so the stakeholders can make best possible decisions

# %% [markdown]
# ## Data

# %% [markdown]
# We are going to investigate the following points to make decisions:
# * the number of restaurants in each neighborhood
# * number of and distance to Chinese restaurants
# * the distance from Chinese restaurants to the city centre
#
# We are going to leverage the Foursquare (Foursquare API) location data to explore the number of restaurants and the cuisine in every neighborhood

# %% [markdown]
# #### Use geopy library to get the latitude and longitude values of Toronto.

# %%
#first import all modules needed
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files
 # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

print('Libraries imported.')
# Out:
# Libraries imported.

# %% [markdown]
# #### Define Foursquare Credentials and Version

# %%
CLIENT_ID = 'BWAMIB5QU5TOZW1YPF5GSVWVCZ5HUDSNU5COQSKSJYO2QKT2' # your Foursquare ID
CLIENT_SECRET = '3VI5IPMCC4A2UN4EDOQSW0C4MNLOWX4PIKMRNK4FL2KLTFP2' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: BWAMIB5QU5TOZW1YPF5GSVWVCZ5HUDSNU5COQSKSJYO2QKT2
# CLIENT_SECRET:3VI5IPMCC4A2UN4EDOQSW0C4MNLOWX4PIKMRNK4FL2KLTFP2

# %%
address = 'Toronto, CA'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Toronto are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Toronto are 43.6534817, -79.3839347.

# %% [markdown]
# #### latitude/longitude <=> X/Y co-ordinates

# %%
import shapely.geometry

import pyproj

import math

def lonlat_to_xy(lon, lat):
    proj_latlon = pyproj.Proj(proj='latlong',datum='WGS84')
    proj_xy = pyproj.Proj(proj="utm", zone=33, datum='WGS84')
    xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
    return xy[0], xy[1]

def xy_to_lonlat(x, y):
    proj_latlon = pyproj.Proj(proj='latlong',datum='WGS84')
    proj_xy = pyproj.Proj(proj="utm", zone=33, datum='WGS84')
    lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)
    return lonlat[0], lonlat[1]

def calc_xy_distance(x1, y1, x2, y2):
    dx = x2 - x1
    dy = y2 - y1
    return math.sqrt(dx*dx + dy*dy)

# %%
print('Coordinate transformation check')
print('-------------------------------')
print('Toronto center longitude={}, latitude={}'.format(longitude, latitude))
x, y = lonlat_to_xy(longitude, latitude)
print('Toronto center X/Y co-ordinates X={}, Y={}'.format(x, y))
lo, la = xy_to_lonlat(x, y)
print('Toronto center longitude={}, latitude={}'.format(lo, la))
# Out:
# Coordinate transformation check
# -------------------------------
# Toronto center longitude=-79.3839347, latitude=43.6534817
# Toronto center X/Y co-ordinates X=-5310527.241020994, Y=10507538.454385541
# Toronto center longitude=-79.3839347000005, latitude=43.653481699999766
# <ipython-input-5-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-5-20aa3bfd6701>:16: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   lonlat = pyproj.transform(proj_xy, proj_latlon, x, y)

# %% [markdown]
# #### get neighborhoods in Toronto

# %%
import urllib.request
url="https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M"
page=urllib.request.urlopen(url)
from bs4 import BeautifulSoup
soup = BeautifulSoup(page, "html.parser")
all_tables=soup.find_all("table")
right_table=soup.find('table', class_='wikitable sortable')

A=[]
B=[]
C=[]
for row in right_table.findAll("tr"):
    cells=row.findAll("td")
    if len(cells)==3:
        A.append(cells[0].find(text=True))
        B.append(cells[1].find(text=True))
        C.append(cells[2].find(text=True))

def remove_useless(lst):
    lst_r=[]
    for i in lst:
        i=i[:-1]
        lst_r.append(i)
    return lst_r

A=remove_useless(A)
B=remove_useless(B)
C=remove_useless(C)

import pandas as pd
df=pd.DataFrame(A,columns=["PostalCode"])
df["Borough"]=B
df["Neighborhood"]=C
df

df_valid=df[df["Borough"]!="Not assigned"]
df_valid=df_valid.reset_index().drop(["index"],axis=1)
df_valid

for i in range(len(df_valid)):
    if df_valid.loc[i,"Neighborhood"]=="Not assigned":
        df_valid.loc[i,"Neighborhood"]=df_valid.loc[i,"Borough"]
        
geo_data=pd.read_csv("E:/Coursea/capstone/geo.csv")
geo=pd.DataFrame(columns=geo_data.columns)
for i in A:
    part=geo_data[geo_data["Postal Code"]==i]
    geo=pd.concat([geo,part])

lat=geo["Latitude"].values.tolist()
long=geo["Longitude"].values.tolist()

df_valid["Longitude"]=long
df_valid["Latitude"]=lat

df_valid
# Out:
#     PostalCode           Borough  \
# 0          M3A        North York
# 1          M4A        North York
# 2          M5A  Downtown Toronto
# 3          M6A        North York
# 4          M7A  Downtown Toronto
# 5          M9A         Etobicoke
# 6          M1B       Scarborough
# 7          M3B        North York
# 8          M4B         East York
# 9          M5B  Downtown Toronto
# 10         M6B        North York
# 11         M9B         Etobicoke
# 12         M1C       Scarborough
# 13         M3C        North York
# 14         M4C         East York
# 15         M5C  Downtown Toronto
# 16         M6C              York
# 17         M9C         Etobicoke
# 18         M1E       Scarborough
# 19         M4E      East Toronto
# 20         M5E  Downtown Toronto
# 21         M6E              York
# 22         M1G       Scarborough
# 23         M4G         East York
# 24         M5G  Downtown Toronto
# 25         M6G  Downtown Toronto
# 26         M1H       Scarborough
# 27         M2H        North York
# 28         M3H        North York
# 29         M4H         East York
# 30         M5H  Downtown Toronto
# 31         M6H      West Toronto
#
# 101  Old Mill South, King's Mill Park, Sunnylea, Hu... -79.498509  43.636258
# 102  Mimico NW, The Queensway West, South of Bloor,... -79.520999  43.628841

# %%
import folium

map_toronto = folium.Map(location=[latitude, longitude], zoom_start=11)

# add markers to map
for lat, lng, borough, neighborhood in zip(df_valid['Latitude'], df_valid['Longitude'], df_valid['Borough'], df_valid['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
long=df_valid["Longitude"].tolist()
lat=df_valid["Latitude"].tolist()
geo_to_xy=[]
for i in range(len(long)):
    x,y=lonlat_to_xy(long[i],lat[i])
    geo_to_xy.append((x,y))
# Out:
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)

# %%
X_coord=[]
Y_coord=[]
for i in range(len(geo_to_xy)):
    x=geo_to_xy[i][0]
    y=geo_to_xy[i][1]
    X_coord.append(x)
    Y_coord.append(y)

# %%
x_toronto,y_toronto=lonlat_to_xy(longitude, latitude)
distance_to_centre=[]
for i in range(len(geo_to_xy)):
    distance=calc_xy_distance(x_toronto, y_toronto, geo_to_xy[i][0], geo_to_xy[i][1])
    distance_to_centre.append(distance)
# Out:
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)

# %%
df_valid["X"]=X_coord
df_valid["Y"]=Y_coord
df_valid["distance to centre"]=distance_to_centre
df_valid.head()
# Out:
#   PostalCode           Borough                                 Neighborhood  \
# 0        M3A        North York                                    Parkwoods
# 1        M4A        North York                             Victoria Village
# 2        M5A  Downtown Toronto                    Regent Park, Harbourfront
# 3        M6A        North York             Lawrence Manor, Lawrence Heights
# 4        M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government
#
#    Longitude   Latitude             X             Y  distance to centre
# 0 -79.329656  43.753259 -5.295352e+06  1.049954e+07        17156.471845
# 1 -79.315572  43.725882 -5.299879e+06  1.049839e+07        14040.948724
# 2 -79.360636  43.654260 -5.310700e+06  1.050483e+07         2710.884442
# 3 -79.464763  43.718518 -5.299146e+06  1.051571e+07        14010.776289
# 4 -79.389494  43.662301 -5.309053e+06  1.050803e+07         1552.537639

# %%
food_cat="4bf58dd8d48988d145941735"
chinese_restaurant_cate=["52af3a5e3cf9994f4e043bea","52af3a723cf9994f4e043bec","52af3a7c3cf9994f4e043bed","58daa1558bbb0b01f18ec1d3",
                         "52af3a673cf9994f4e043beb","52af3a903cf9994f4e043bee","4bf58dd8d48988d1f5931735","52af3a9f3cf9994f4e043bef",
                         "52af3aaa3cf9994f4e043bf0","52af3ab53cf9994f4e043bf1","52af3abe3cf9994f4e043bf2","52af3ac83cf9994f4e043bf3",
                         "52af3ad23cf9994f4e043bf4","52af3add3cf9994f4e043bf5","52af3af23cf9994f4e043bf7","52af3ae63cf9994f4e043bf6",
                         "52af3afc3cf9994f4e043bf8","52af3b053cf9994f4e043bf9","52af3b213cf9994f4e043bfa","52af3b213cf9994f4e043bfa",
                         "52af3b293cf9994f4e043bfb","52af3b343cf9994f4e043bfc","52af3b3b3cf9994f4e043bfd","52af3b463cf9994f4e043bfe",
                         "52af3b633cf9994f4e043c01","52af3b513cf9994f4e043bff","52af3b593cf9994f4e043c00","52af3b6e3cf9994f4e043c02",
                         "52af3b773cf9994f4e043c03","52af3b813cf9994f4e043c04","52af3b893cf9994f4e043c05","52af3b913cf9994f4e043c06",
                         "52af3b9a3cf9994f4e043c07","52af3ba23cf9994f4e043c08"]

# %%
radius=1000
LIMIT=50
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&categoryId={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION,food_cat,radius, LIMIT)
results = requests.get(url).json()

# %%
venues=results['response']['venues']
from pandas.io.json import json_normalize
dataframe = json_normalize(venues)
dataframe
# Out:
# <ipython-input-15-d523b7159421>:3: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   dataframe = json_normalize(venues)
#                           id                                            name  \
# 0   5cb7b58a9d74680039974a4a                                    Artisan Plus
# 1   5bf765b2c5b11c002c1c8fc6                                            ZenQ
# 2   4b2027b5f964a520f82d24e3                   Hong Shing Chinese Restaurant
# 3   5bd0acba911fc4002cb6ac94                                    Yang Teashop
# 4   59ebff82d0a1496688eb92b0                   DAGU RICE NOODLE Toronto 大鼓米线
# 5   4c1a5be68b3aa5932f7a955f                                   Asian Gourmet
# 6   4c69740b8d22c9284d42b745                      Wah Too Seafood Restaurant
# 7   4e95cb3930f82cbde9ed2407                                    Shanghai 360
# 8   4ba573a5f964a5207c0839e3                      Rol Jui Seafood Restaurant
# 9   5cadd69f3092be0039a9ba17                                        Chi Chop
# 10  5750b013498e755287c6de97              Some Time BBQ Grill Restaurant 碳烤屋
# 11  4adb62a5f964a520c62621e3             New Hong Fatt BBQ Restaurant 新鴻發美食軒
# 12  4afb1ff7f964a5205b1b22e3                                    Spring Rolls
# 13  5deafc3289d1b10008c90050                                 Zhang's Kitchen
# 14  57b8e03a498e48d4813ab5af                      Harmony Chinese Restaurant
# 15  5b80a8eea2c00b002c0b2244                    Four Four South Village 四四南村
# 16  4c659863e1da1b8d1ca698c3                                      China King
# 17  4b88188ff964a5207bdf31e3                                Szechuan Express
# 18  4adf80b9f964a5202f7b21e3                    Good View Chinese Restaurant
# 19  4ad4c060f964a52082f720e3                     Hua Sang Seafood Restaurant
# 20  4cc8798ab3f5224b6d39ef20                                       China Wok
# 21  5c5b8685c5b11c00398a0e6a                     Toronto Big Bowl Restaurant
# 22  4ff0bea6e4b07cca83f24036                                 All Day Dim Sum
# 23  4fb00d0ce4b021a2c0a0b62a                               Beijing Dumplings
# 24  4c15280ea5eb76b0c4d9c2b7                              Tasty Chinese Food
# 25  4b06d06df964a520b3f022e3                          Ho Ga Oriental Cuisine
# 26  4c38ad930a71c9b6201141c9                                    Dim Sum Cafe
# 27  4afc541df964a5209b2122e3                                      Manchu Wok
# 28  4b421f7cf964a52025cd25e3                                      Manchu Wok
# 29  5cedac507564f7002c310321  Yang's Braised Chicken Rice(ChinaTown)杨铭宇黄焖鸡米饭
# 30  4ada4857f964a520df2021e3                            House of Gourmet 滿庭芳
# 31  4e076d76d4c03ae0b9c9e065                      Sen Ming Garden Restaurant
# 32  58e91d60e0adac258fcea481                          GB Hand-Pulled Noodles
# 33  4c0558809a7920a1a581d279                                      Woklicious
# 34  4c6c73a9d68a9c741b5c696b                             A Taste of Shanghai
# 35  4b70af61f964a5208d292de3                                  Fragrant Foods
# 36  588541549343e011e4a22fbb                                       Charidise
# 37  4b589c8ff964a520396128e3                                Zhu's Restaurant
# 38  4e8f34d861afcfde295d013e                                      China Wall
# 39  51e1cf9a498e3c12c7f3ca22                        spring garden Restaurant
# 40  4f0f907ce4b067f66dbc8a05                             Rong Hua Restaurant
# 41  4cae3107cbab236ae33c8e73                                      Manchu Wok
# 42  4fd3ea3ee4b0191b9c2b1aff                        Rosewood Chinese Cuisine
# 43  4adb5472f964a520fc2521e3                                Asian Legend 味香村
# 44  4e66a12da809802674fde6c3                                Szechuan Express
# 45  51b5fe4f498e28cccf75f622                                        Mean Bao
# 46  4ddbe8697d8b771c0b09b885                 Dim Sum King Seafood Restaurant
# 47  4aea2b14f964a520ebb921e3                                 Fine Asian Bowl
# 48  4b287167f964a520659324e3                     Wah Sing Seafood Restaurant
#
#                                            categories    referralId  hasPerk  \
# 0   [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1595306647    False
# 1   [{'id': '52e81612bcbc57f1066b7a0c', 'name': 'B...  v-1595306647    False
# 2   [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1595306647    False
# 3   [{'id': '4bf58dd8d48988d1dc931735', 'name': 'T...  v-1595306647    False
# 4   [{'id': '4bf58dd8d48988d1d1941735', 'name': 'N...  v-1595306647    False
# 5   [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1595306647    False
# 6   [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1595306647    False
# 7   [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1595306647    False
# 8   [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1595306647    False
# 9   [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1595306647    False
# 10  [{'id': '52af3b773cf9994f4e043c03', 'name': 'S...  v-1595306647    False
# 11  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1595306647    False
# 12  [{'id': '4bf58dd8d48988d142941735', 'name': 'A...  v-1595306647    False
# 13  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1595306647    False
# 14  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1595306647    False
# 15  [{'id': '52af3b813cf9994f4e043c04', 'name': 'T...  v-1595306647    False
# 16  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1595306647    False
# 17  [{'id': '4bf58dd8d48988d142941735', 'name': 'A...  v-1595306647    False
# 18  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1595306647    False
# 19  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1595306647    False
# 20  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1595306647    False
# 21  [{'id': '52af3b773cf9994f4e043c03', 'name': 'S...  v-1595306647    False
# 22  [{'id': '4bf58dd8d48988d1f5931735', 'name': 'D...  v-1595306647    False
# 23  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1595306647    False
# 24  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1595306647    False
# 25  [{'id': '4bf58dd8d48988d142941735', 'name': 'A...  v-1595306647    False
# 26  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1595306647    False
# 27  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1595306647    False
# 28  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1595306647    False
# 29  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1595306647    False
# 30  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1595306647    False
# 31  [{'id': '4bf58dd8d48988d1f5931735', 'name': 'D...  v-1595306647    False
# 32  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1595306647    False
# 33  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1595306647    False
# 34  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1595306647    False
# 35  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1595306647    False
# 36  [{'id': '52e81612bcbc57f1066b7a0c', 'name': 'B...  v-1595306648    False
# 37  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1595306648    False
# 38  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1595306648    False
# 39  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1595306648    False
# 40  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1595306648    False
# 41  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1595306648    False
# 42  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1595306648    False
# 43  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1595306648    False
# 44  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1595306648    False
# 45  [{'id': '4bf58dd8d48988d1c5941735', 'name': 'S...  v-1595306648    False
# 46  [{'id': '4bf58dd8d48988d1f5931735', 'name': 'D...  v-1595306648    False
# 47  [{'id': '4bf58dd8d48988d14a941735', 'name': 'V...  v-1595306648    False
# 48  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1595306648    False
#
#                             location.address  location.lat  location.lng  \
# 0                        122 Dundas Street W     43.655685    -79.384330
# 1                        171 Dundas Street W     43.654911    -79.387266
# 2                            195 Dundas St W     43.654925    -79.387089
# 3                            183 Dundas St W     43.655061    -79.386637
# 4                            111 Dundas St W     43.655632    -79.384280
# 5                                        NaN     43.649288    -79.378183
# 6                             56 Centre Ave.     43.654833    -79.387206
# 7                              220 Yonge St.     43.654506    -79.380894
# 8                              472 Dundas St     43.653153    -79.396877
# 9                               372 Yonge St     43.658730    -79.382057
# 10                        988 Baldwin Street     43.655874    -79.393826
# 11                           443 Dundas St W     43.653342    -79.396007
# 12                           40 Dundas St. W     43.655997    -79.382455
# 13                                 13 Elm St     43.657630    -79.382324
# 14                    478 Dundas Street West     43.653427    -79.397030
# 15                                       NaN     43.662280    -79.383712
# 16                                 444 Yonge     43.660669    -79.383905
# 17                               333 Bay St.     43.650656    -79.379462
# 18                    132 Dundas Street East     43.656791    -79.376139
# 19                         41 Baldwin Street     43.655986    -79.393703
# 20                   25 King St. W, Ste. 152     43.648124    -79.379121
# 21                             45 Baldwin St     43.655934    -79.393731
# 22                                       NaN     43.661779    -79.381450
# 23                                       NaN     43.656416    -79.383783
# 24                     Village by the Grange     43.653757    -79.390757
# 25                            121 King St. W     43.648043    -79.383108
# 26                         114-140 D'Arcy St     43.653394    -79.397072
# 27  200 Front ST West Unit F004,Simcoe Place     43.644935    -79.386151
# 28    200 Wellington Street West,Metrocentre     43.645858    -79.387830
# 29                         414 Dundas St. W.     43.653717    -79.395030
# 30                           484 Dundas St W     43.653273    -79.397230
# 31                           436 Dundas St W     43.653397    -79.395961
# 32                          66 Edward Street     43.656434    -79.383783
# 33                           123 Queen St. W     43.651750    -79.383036
# 34   442 Dundas Street West, Basement Level.     43.657634    -79.384020
# 35                           478 Dundas West     43.653657    -79.395549
# 36                             27 Baldwin St     43.655985    -79.393233
# 37                          1 Baldwin Street     43.656277    -79.392393
# 38                                       NaN     43.649020    -79.380185
# 39                                       NaN     43.655209    -79.393444
# 40                           478 Dundas St W     43.653144    -79.397133
# 41                   Eaton Centre Food Court     43.652656    -79.380308
# 42                         463 Dundas St. W.     43.653171    -79.396710
# 43                           418 Dundas St W     43.653603    -79.395047
# 44                             220 Yonge St.     43.655108    -79.380790
# 45                         275 Dundas St. W.     43.653595    -79.390534
# 46                           421 Dundas St W     43.653503    -79.395405
# 47                             271 Yonge St.     43.655387    -79.380326
# 48                         47 Baldwin Street     43.655936    -79.393783
#
#                               location.labeledLatLngs  location.distance  \
# 0   [{'label': 'display', 'lat': 43.655685, 'lng':...                247
# 1   [{'label': 'display', 'lat': 43.654911, 'lng':...                311
# 2   [{'label': 'display', 'lat': 43.65492521335936...                300
# 3   [{'label': 'display', 'lat': 43.655061, 'lng':...                279
# 4   [{'label': 'display', 'lat': 43.65563207103592...                240
# 5   [{'label': 'display', 'lat': 43.649288, 'lng':...                657
# 6   [{'label': 'display', 'lat': 43.65483285234745...                303
# 7   [{'label': 'display', 'lat': 43.65450604545589...                270
# 8   [{'label': 'display', 'lat': 43.65315284886056...               1043
# 9   [{'label': 'display', 'lat': 43.65873, 'lng': ...                603
# 10  [{'label': 'display', 'lat': 43.655874, 'lng':...                839
# 11  [{'label': 'display', 'lat': 43.65334218256763...                972
# 12  [{'label': 'display', 'lat': 43.65599737998799...                304
# 13  [{'label': 'display', 'lat': 43.65763, 'lng': ...                479
# 14  [{'label': 'display', 'lat': 43.653427, 'lng':...               1054
# 15  [{'label': 'display', 'lat': 43.66228, 'lng': ...                979
# 16  [{'label': 'display', 'lat': 43.66066880084518...                800
# 17  [{'label': 'display', 'lat': 43.65065595409705...                478
# 18  [{'label': 'display', 'lat': 43.65679124992238...                727
# 19  [{'label': 'display', 'lat': 43.65598631977402...                834
# 20  [{'label': 'display', 'lat': 43.64812435776088...                711
# 21  [{'label': 'display', 'lat': 43.655934, 'lng':...                834
# 22  [{'label': 'display', 'lat': 43.661779, 'lng':...                945
# 23  [{'label': 'display', 'lat': 43.65641597882597...                326
# 24  [{'label': 'display', 'lat': 43.65375663396815...                550
# 25  [{'label': 'display', 'lat': 43.64804326543631...                609
# 26  [{'label': 'display', 'lat': 43.65339440315915...               1058
# 27  [{'label': 'display', 'lat': 43.644935, 'lng':...                968
# 28  [{'label': 'display', 'lat': 43.645858, 'lng':...                904
# 29  [{'label': 'display', 'lat': 43.653717, 'lng':...                894
# 30  [{'label': 'display', 'lat': 43.65327328119581...               1071
# 31  [{'label': 'display', 'lat': 43.653397, 'lng':...                968
# 32  [{'label': 'display', 'lat': 43.65643422548463...                328
# 33  [{'label': 'display', 'lat': 43.65174989639756...                205
# 34  [{'label': 'display', 'lat': 43.657634, 'lng':...                462
# 35  [{'label': 'display', 'lat': 43.653657, 'lng':...                935
# 36  [{'label': 'display', 'lat': 43.65598547591116...                799
# 37  [{'label': 'display', 'lat': 43.656277, 'lng':...                748
# 38  [{'label': 'display', 'lat': 43.64902, 'lng': ...                581
# 39  [{'label': 'display', 'lat': 43.65520868595963...                789
# 40  [{'label': 'display', 'lat': 43.65314393874490...               1063
# 41  [{'label': 'display', 'lat': 43.652656, 'lng':...                306
# 42  [{'label': 'display', 'lat': 43.65317123090316...               1029
# 43  [{'label': 'display', 'lat': 43.65360271388312...                895
# 44  [{'label': 'display', 'lat': 43.65510823589989...                311
# 45  [{'label': 'display', 'lat': 43.65359484555407...                531
# 46  [{'label': 'display', 'lat': 43.653503, 'lng':...                923
# 47  [{'label': 'display', 'lat': 43.6553866, 'lng'...                359
# 48  [{'label': 'display', 'lat': 43.65593557082916...                838
#
#    location.postalCode location.cc location.city location.state  \
# 0              M5G 1C3          CA       Toronto             ON
# 1              M5G 1C8          CA       Toronto             ON
# 2              M5G 1C7          CA       Toronto             ON
# 3              M5G 1C7          CA       Toronto             ON
# 4              M5G 1C4          CA       Toronto             ON
# 5                  NaN          CA           NaN            NaN
# 6              M5G 1R5          CA       Toronto             ON
# 7                  NaN          CA       Toronto             ON
# 8                  NaN          CA       Toronto             ON
# 9              M5B 1S6          CA       Toronto             ON
# 10                 NaN          CA       Toronto             ON
# 11                 NaN          CA       Toronto             ON
# 12             M5G 2C2          CA       Toronto             ON
# 13             M5G 1H1          CA       Toronto             ON
# 14             M5T 1G9          CA       Toronto             ON
# 15             M4Y 1X5          CA       Toronto             ON
# 16                 NaN          CA       Toronto             ON
# 17                 NaN          CA       Toronto             ON
# 18                 NaN          CA       Toronto             ON
# 19             M5T 1L1          CA       Toronto             ON
# 20             M5L 1E2          CA       Toronto             ON
# 21             M5T 1L1          CA       Toronto             ON
# 22                 NaN          CA           NaN            NaN
# 23                 NaN          CA       Toronto             ON
# 24                 NaN          CA       Toronto             ON
# 25             M5H 3T9          CA       Toronto             ON
# 26             M5T 1K2          CA       Toronto             ON
# 27             M5V 3K2          CA       Toronto             ON
# 28             M5V 3C7          CA       Toronto             ON
# 29             M5T 1G7          CA       Toronto             ON
# 30             M5T 1G9          CA       Toronto             ON
# 31                 NaN          CA       Toronto             ON
# 32             M5G 1C9          CA       Toronto             ON
# 33             M5H 3M9          CA       Toronto             ON
# 34                 NaN          CA       Toronto             ON
# 35                 NaN          CA       Toronto             ON
# 36             M5T 1L1          CA       Toronto             ON
# 37                 NaN          CA       Toronto             ON
# 38                 NaN          CA       Toronto             ON
# 39                 NaN          CA           NaN            NaN
# 40                 NaN          CA           NaN            NaN
# 41                 NaN          CA       Toronto             ON
# 42             M5T 1G8          CA       Toronto             ON
# 43             M5T 1G7          CA       Toronto             ON
# 44             M5B 2H1          CA       Toronto             ON
# 45                 NaN          CA       Toronto             ON
# 46             M5T 2W4          CA       Toronto             ON
# 47             M5B 1N8          CA       Toronto             ON
# 48             M5T 1L1          CA       Toronto             ON
#
#    location.country                          location.formattedAddress  \
# 0            Canada  [122 Dundas Street W, Toronto ON M5G 1C3, Canada]
# 1            Canada  [171 Dundas Street W (Dundas & Centre), Toront...
# 2            Canada  [195 Dundas St W (at University Ave), Toronto ...
# 3            Canada      [183 Dundas St W, Toronto ON M5G 1C7, Canada]
# 4            Canada  [111 Dundas St W (btwn Bay & Elizabeth St), To...
# 5            Canada                                           [Canada]
# 6            Canada       [56 Centre Ave., Toronto ON M5G 1R5, Canada]
# 7            Canada  [220 Yonge St. (in Urban Eatery, Toronto Eaton...
# 8            Canada      [472 Dundas St (Spadina), Toronto ON, Canada]
# 9            Canada         [372 Yonge St, Toronto ON M5B 1S6, Canada]
# 10           Canada           [988 Baldwin Street, Toronto ON, Canada]
# 11           Canada  [443 Dundas St W (at Huron St), Toronto ON, Ca...
# 12           Canada  [40 Dundas St. W (at Yonge St.), Toronto ON M5...
# 13           Canada            [13 Elm St, Toronto ON M5G 1H1, Canada]
# 14           Canada  [478 Dundas Street West, Toronto ON M5T 1G9, C...
# 15           Canada                       [Toronto ON M4Y 1X5, Canada]
# 16           Canada                    [444 Yonge, Toronto ON, Canada]
# 17           Canada  [333 Bay St. (at Adelaide St. W), Toronto ON, ...
# 18           Canada       [132 Dundas Street East, Toronto ON, Canada]
# 19           Canada    [41 Baldwin Street, Toronto ON M5T 1L1, Canada]
# 20           Canada  [25 King St. W, Ste. 152 (Wellington St. W.), ...
# 21           Canada        [45 Baldwin St, Toronto ON M5T 1L1, Canada]
# 22           Canada                                           [Canada]
# 23           Canada                  [Bay and Elm, Toronto ON, Canada]
# 24           Canada        [Village by the Grange, Toronto ON, Canada]
# 25           Canada  [121 King St. W (in Standard Life Building, Co...
# 26           Canada    [114-140 D'Arcy St, Toronto ON M5T 1K2, Canada]
# 27           Canada  [200 Front ST West Unit F004,Simcoe Place (in ...
# 28           Canada  [200 Wellington Street West,Metrocentre (at Me...
# 29           Canada  [414 Dundas St. W. (at Beverley St.), Toronto ...
# 30           Canada  [484 Dundas St W (at Spadina Ave), Toronto ON ...
# 31           Canada              [436 Dundas St W, Toronto ON, Canada]
# 32           Canada  [66 Edward Street (Bay Street), Toronto ON M5G...
# 33           Canada  [123 Queen St. W (at Sheraton Centre Hotel), T...
# 34           Canada  [442 Dundas Street West, Basement Level., Toro...
# 35           Canada              [478 Dundas West, Toronto ON, Canada]
# 36           Canada  [27 Baldwin St (Henry St), Toronto ON M5T 1L1,...
# 37           Canada  [1 Baldwin Street (at McCaul), Toronto ON, Can...
# 38           Canada                               [Toronto ON, Canada]
# 39           Canada                                           [Canada]
# 40           Canada                          [478 Dundas St W, Canada]
# 41           Canada      [Eaton Centre Food Court, Toronto ON, Canada]
# 42           Canada  [463 Dundas St. W. (at Larch St.), Toronto ON ...
# 43           Canada  [418 Dundas St W (btwn Beverley & Huron St), T...
# 44           Canada  [220 Yonge St. (in Urban Eatery, Toronto Eaton...
# 45           Canada            [275 Dundas St. W., Toronto ON, Canada]
# 46           Canada      [421 Dundas St W, Toronto ON M5T 2W4, Canada]
# 47           Canada  [271 Yonge St. (btwn Dundas St. E & Shuter St....
# 48           Canada    [47 Baldwin Street, Toronto ON M5T 1L1, Canada]
#
#                      location.crossStreet venuePage.id location.neighborhood
# 0                                     NaN          NaN                   NaN
# 1                         Dundas & Centre          NaN                   NaN
# 2                       at University Ave     60327598                   NaN
# 3                                     NaN          NaN                   NaN
# 4                 btwn Bay & Elizabeth St          NaN                   NaN
# 5                                     NaN          NaN                   NaN
# 6                                     NaN          NaN                   NaN
# 7   in Urban Eatery, Toronto Eaton Centre          NaN                   NaN
# 8                                 Spadina          NaN                   NaN
# 9                                     NaN          NaN                   NaN
# 10                                    NaN          NaN                   NaN
# 11                            at Huron St          NaN                   NaN
# 12                           at Yonge St.          NaN                   NaN
# 13                                    NaN          NaN                   NaN
# 14                                    NaN          NaN                   NaN
# 15                                    NaN          NaN                   NaN
# 16                                    NaN          NaN                   NaN
# 17                      at Adelaide St. W          NaN                   NaN
# 18                                    NaN          NaN                   NaN
# 19                                    NaN          NaN                   NaN
# 20                      Wellington St. W.          NaN                   NaN
# 21                                    NaN          NaN                   NaN
# 22                                    NaN          NaN                   NaN
# 23                            Bay and Elm          NaN                   NaN
# 24                                    NaN          NaN                   NaN
# 25   in Standard Life Building, Concourse          NaN                   NaN
# 26                                    NaN          NaN                   NaN
# 27             in Simcoe Place Food Court          NaN                   NaN
# 28                        at Metro Centre          NaN                   NaN
# 29                        at Beverley St.          NaN                   NaN
# 30                         at Spadina Ave          NaN             Chinatown
# 31                                    NaN          NaN                   NaN
# 32                             Bay Street          NaN                   NaN
# 33               at Sheraton Centre Hotel          NaN                   NaN
# 34                                    NaN          NaN                   NaN
# 35                                    NaN          NaN                   NaN
# 36                               Henry St          NaN                   NaN
# 37                              at McCaul          NaN                   NaN
# 38                                    NaN          NaN                   NaN
# 39                                    NaN          NaN                   NaN
# 40                                    NaN          NaN                   NaN
# 41                                    NaN          NaN                   NaN
# 42                           at Larch St.          NaN                   NaN
# 43               btwn Beverley & Huron St          NaN                   NaN
# 44  in Urban Eatery, Toronto Eaton Centre          NaN                   NaN
# 45                                    NaN          NaN                   NaN
# 46                                    NaN          NaN                   NaN
# 47         btwn Dundas St. E & Shuter St.          NaN                   NaN
# 48                                    NaN    115982783                   NaN

# %%
df_valid.head()
# Out:
#   PostalCode           Borough                                 Neighborhood  \
# 0        M3A        North York                                    Parkwoods
# 1        M4A        North York                             Victoria Village
# 2        M5A  Downtown Toronto                    Regent Park, Harbourfront
# 3        M6A        North York             Lawrence Manor, Lawrence Heights
# 4        M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government
#
#    Longitude   Latitude             X             Y  distance to centre
# 0 -79.329656  43.753259 -5.295352e+06  1.049954e+07        17156.471845
# 1 -79.315572  43.725882 -5.299879e+06  1.049839e+07        14040.948724
# 2 -79.360636  43.654260 -5.310700e+06  1.050483e+07         2710.884442
# 3 -79.464763  43.718518 -5.299146e+06  1.051571e+07        14010.776289
# 4 -79.389494  43.662301 -5.309053e+06  1.050803e+07         1552.537639

# %%
toronto_lat=df_valid["Latitude"].tolist()
toronto_long=df_valid["Longitude"].tolist()
toronto_borough=df_valid["Borough"].tolist()
toronto_distance=df_valid["distance to centre"].tolist()
toronto_Neighborhood=df_valid["Neighborhood"].tolist()
restaurants_in_neighborhood=pd.DataFrame(columns=dataframe.columns)

# %%
radius=1000
LIMIT=50
for i in range(len(toronto_lat)):
    url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&categoryId={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, toronto_lat[i], toronto_long[i], VERSION,food_cat,radius, LIMIT)
    results = requests.get(url).json()
    venues=results['response']['venues']
    dataframe = json_normalize(venues)
    dataframe["Neighborhood"]=[toronto_Neighborhood[i]]*len(dataframe)
    dataframe["Borough"]=[toronto_borough[i]]*len(dataframe)
    dataframe["Latitude"]=[toronto_lat[i]]*len(dataframe)
    dataframe["Longitude"]=[toronto_long[i]]*len(dataframe)
    restaurants_in_neighborhood=pd.concat([restaurants_in_neighborhood,dataframe])
# Out:
# <ipython-input-17-4b5c984ffcd0>:7: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   dataframe = json_normalize(venues)

# %%
restaurants_in_neighborhood.reset_index(inplace=True)
restaurants_in_neighborhood=restaurants_in_neighborhood.drop(["index"],axis=1)

# %%
restaurants_in_neighborhood.head(20)
# Out:
#                           id                                            name  \
# 0   4c0150f4716bc9b65b9dbb55                             Spicy Chicken House
# 1   4be21e1921d5a59390ec1511                                  Peking Express
# 2   4bace084f964a520ca143be3                                  Oriental Taste
# 3   4bca992068f976b017d35f83                                   China Gourmet
# 4   4c17c23a6a21c9b6b901c897                              Ying Ying Soy Food
# 5   5b3aa3ec029a55002c3f0338                                  Bamboo Kitchen
# 6   4f73a473e4b0c1f445d21c78                                   Huayu Kitchen
# 7   4ef0e4ece5e89bf2782272f4                                  Ho Mei Kitchen
# 8   553c2ae7498e53f7c3086919                                Kanpai Snack Bar
# 9   4b64d531f964a52090d32ae3                                    On The Rocks
# 10  55f07a51498ef8afddf53c9c                                        Mean Bao
# 11  4bd36425a8b3a59345e3695f                                     Noodle King
# 12  5349f3fa11d20b02057c5e93                         Lucky Dragon Restaurant
# 13  5e3215f5c3496d000827e38b                              Bone Soup Malatang
# 14  5e0a423b482d2d0008749b4e                                 Mabu Generation
# 15  4ad4c05ff964a52013f720e3                                Not Just Noodles
# 16  5cfbccfec5b11c002ce7e414                   Mo Gou Yan Lanzhou Noodle 磨沟沿
# 17  5c66fbf3b3d8e2002c5e1f00                               Spicy Incredibowl
# 18  5cedac507564f7002c310321  Yang's Braised Chicken Rice(ChinaTown)杨铭宇黄焖鸡米饭
# 19  5b80a8eea2c00b002c0b2244                    Four Four South Village 四四南村
#
#                                            categories    referralId hasPerk  \
# 0   [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1595289144   False
# 1   [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1595289144   False
# 2   [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1595289144   False
# 3   [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1595289144   False
# 4   [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1595289144   False
# 5   [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1595289144   False
# 6   [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1595289144   False
# 7   [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1595289144   False
# 8   [{'id': '52af3b813cf9994f4e043c04', 'name': 'T...  v-1595289144   False
# 9   [{'id': '4bf58dd8d48988d120941735', 'name': 'K...  v-1595289144   False
# 10  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1595289144   False
# 11  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1595289144   False
# 12  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1595289144   False
# 13  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1595289145   False
# 14  [{'id': '52af3b813cf9994f4e043c04', 'name': 'T...  v-1595289145   False
# 15  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1595289145   False
# 16  [{'id': '4bf58dd8d48988d1d1941735', 'name': 'N...  v-1595289145   False
# 17  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1595289145   False
# 18  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1595289145   False
# 19  [{'id': '52af3b813cf9994f4e043c04', 'name': 'T...  v-1595289145   False
#
#          location.address             location.crossStreet  location.lat  \
# 0     1277 York Mills Rd.                              NaN     43.760639
# 1                     NaN                              NaN     43.656692
# 2            329 Queen st                        Parliment     43.655304
# 3          235 Carlton St                 at Parliament St     43.664180
# 4         93 Front St. E.           in St. Lawrence Market     43.648994
# 5       292 Parliament st                              NaN     43.658620
# 6                     NaN                              NaN     43.654148
# 7       236 Sherbourne St                              NaN     43.658030
# 8          252 Carlton St                at Parliament St.     43.664331
# 9   169 Front Street East                 at Sherbourne St     43.650408
# 10         181 Carlaw Ave                   Queen & Carlaw     43.659232
# 11   3240 Dufferin St, #4  Btwn Hwy 401 and Lawrence Ave W     43.725238
# 12       3203 Dufferin St                         Samor Rd     43.718342
# 13                    NaN                              NaN     43.663666
# 14       578 Yonge street                        Wellesley     43.665236
# 15          570 Yonge St.                 Wellesley Street     43.664970
# 16           760 Yonge St                              NaN     43.669513
# 17        407 Spadina Ave                              NaN     43.656807
# 18      414 Dundas St. W.                  at Beverley St.     43.653717
# 19                    NaN                              NaN     43.662280
#
#     location.lng                            location.labeledLatLngs  \
# 0     -79.325671  [{'label': 'display', 'lat': 43.76063939666398...
# 1     -79.365126  [{'label': 'display', 'lat': 43.6566919000341,...
# 2     -79.365312  [{'label': 'display', 'lat': 43.655304, 'lng':...
# 3     -79.368359  [{'label': 'display', 'lat': 43.6641802410051,...
# 4     -79.371494  [{'label': 'display', 'lat': 43.64899366575782...
# 5     -79.365881  [{'label': 'display', 'lat': 43.65862, 'lng': ...
# 6     -79.357826  [{'label': 'display', 'lat': 43.65414810180664...
# 7     -79.371028  [{'label': 'display', 'lat': 43.65803017091301...
# 8     -79.368065  [{'label': 'display', 'lat': 43.66433093594863...
# 9     -79.368354  [{'label': 'display', 'lat': 43.65040844699981...
# 10    -79.348011  [{'label': 'display', 'lat': 43.659232, 'lng':...
# 11    -79.469876  [{'label': 'display', 'lat': 43.725238, 'lng':...
# 12    -79.455619  [{'label': 'display', 'lat': 43.71834159119308...
# 13    -79.384200  [{'label': 'display', 'lat': 43.663666, 'lng':...
# 14    -79.384803  [{'label': 'display', 'lat': 43.665236, 'lng':...
# 15    -79.384659  [{'label': 'display', 'lat': 43.66496972762233...
# 16    -79.386632  [{'label': 'display', 'lat': 43.669513, 'lng':...
# 17    -79.399315  [{'label': 'display', 'lat': 43.656807, 'lng':...
# 18    -79.395030  [{'label': 'display', 'lat': 43.653717, 'lng':...
# 19    -79.383712  [{'label': 'display', 'lat': 43.66228, 'lng': ...
#
#    location.distance location.postalCode location.cc location.city  \
# 0                881             M3A 1Z5          CA    North York
# 1                451                 NaN          CA           NaN
# 2                394                 NaN          CA       Toronto
# 3               1267             M5A 2L2          CA       Toronto
# 4               1052             M5E 1C3          CA       Toronto
# 5                643             M5A 3A4          CA       Toronto
# 6                226                 NaN          CA           NaN
# 7                936                 M5A          CA       Toronto
# 8               1270                 NaN          CA       Toronto
# 9                755                 NaN          CA       Toronto
# 10              1157             M4M 2S1          CA       Toronto
# 11               853             M6A 2T2          CA       Toronto
# 12               735             M6A 2T2          CA       Toronto
# 13               452             M4Y 1X9          CA       Toronto
# 14               499             M4Y 1Z3          CA       Toronto
# 15               489             M4Y 1Z3          CA       Toronto
# 16               835             M4Y 1R5          CA       Toronto
# 17               999             M5T 2G6          CA       Toronto
# 18              1054             M5T 1G7          CA       Toronto
# 19               465             M4Y 1X5          CA       Toronto
#
#    location.state location.country  \
# 0              ON           Canada
# 1             NaN           Canada
# 2              ON           Canada
# 3              ON           Canada
# 4              ON           Canada
# 5              ON           Canada
# 6             NaN           Canada
# 7              ON           Canada
# 8              ON           Canada
# 9              ON           Canada
# 10             ON           Canada
# 11             ON           Canada
# 12             ON           Canada
# 13             ON           Canada
# 14             ON           Canada
# 15             ON           Canada
# 16             ON           Canada
# 17             ON           Canada
# 18             ON           Canada
# 19             ON           Canada
#
#                             location.formattedAddress venuePage.id  \
# 0   [1277 York Mills Rd., North York ON M3A 1Z5, C...          NaN
# 1                                            [Canada]          NaN
# 2      [329 Queen st (Parliment), Toronto ON, Canada]          NaN
# 3   [235 Carlton St (at Parliament St), Toronto ON...          NaN
# 4   [93 Front St. E. (in St. Lawrence Market), Tor...          NaN
# 5     [292 Parliament st, Toronto ON M5A 3A4, Canada]          NaN
# 6                                            [Canada]          NaN
# 7         [236 Sherbourne St, Toronto ON M5A, Canada]          NaN
# 8   [252 Carlton St (at Parliament St.), Toronto O...          NaN
# 9   [169 Front Street East (at Sherbourne St), Tor...          NaN
# 10  [181 Carlaw Ave (Queen & Carlaw), Toronto ON M...          NaN
# 11  [3240 Dufferin St, #4 (Btwn Hwy 401 and Lawren...          NaN
# 12  [3203 Dufferin St (Samor Rd), Toronto ON M6A 2...          NaN
# 13                       [Toronto ON M4Y 1X9, Canada]          NaN
# 14  [578 Yonge street (Wellesley), Toronto ON M4Y ...          NaN
# 15  [570 Yonge St. (Wellesley Street), Toronto ON ...          NaN
# 16         [760 Yonge St, Toronto ON M4Y 1R5, Canada]          NaN
# 17      [407 Spadina Ave, Toronto ON M5T 2G6, Canada]          NaN
# 18  [414 Dundas St. W. (at Beverley St.), Toronto ...          NaN
# 19                       [Toronto ON M4Y 1X5, Canada]          NaN
#
#    location.neighborhood                                 Neighborhood  \
# 0                    NaN                                    Parkwoods
# 1                    NaN                    Regent Park, Harbourfront
# 2                    NaN                    Regent Park, Harbourfront
# 3                    NaN                    Regent Park, Harbourfront
# 4                    NaN                    Regent Park, Harbourfront
# 5                    NaN                    Regent Park, Harbourfront
# 6                    NaN                    Regent Park, Harbourfront
# 7                    NaN                    Regent Park, Harbourfront
# 8            Cabbagetown                    Regent Park, Harbourfront
# 9                    NaN                    Regent Park, Harbourfront
# 10             Riverside                    Regent Park, Harbourfront
# 11                   NaN             Lawrence Manor, Lawrence Heights
# 12                   NaN             Lawrence Manor, Lawrence Heights
# 13                   NaN  Queen's Park, Ontario Provincial Government
# 14                   NaN  Queen's Park, Ontario Provincial Government
# 15                   NaN  Queen's Park, Ontario Provincial Government
# 16                   NaN  Queen's Park, Ontario Provincial Government
# 17                   NaN  Queen's Park, Ontario Provincial Government
# 18                   NaN  Queen's Park, Ontario Provincial Government
# 19                   NaN  Queen's Park, Ontario Provincial Government
#
#              Borough   Latitude  Longitude
# 0         North York  43.753259 -79.329656
# 1   Downtown Toronto  43.654260 -79.360636
# 2   Downtown Toronto  43.654260 -79.360636
# 3   Downtown Toronto  43.654260 -79.360636
# 4   Downtown Toronto  43.654260 -79.360636
# 5   Downtown Toronto  43.654260 -79.360636
# 6   Downtown Toronto  43.654260 -79.360636
# 7   Downtown Toronto  43.654260 -79.360636
# 8   Downtown Toronto  43.654260 -79.360636
# 9   Downtown Toronto  43.654260 -79.360636
# 10  Downtown Toronto  43.654260 -79.360636
# 11        North York  43.718518 -79.464763
# 12        North York  43.718518 -79.464763
# 13  Downtown Toronto  43.662301 -79.389494
# 14  Downtown Toronto  43.662301 -79.389494
# 15  Downtown Toronto  43.662301 -79.389494
# 16  Downtown Toronto  43.662301 -79.389494
# 17  Downtown Toronto  43.662301 -79.389494
# 18  Downtown Toronto  43.662301 -79.389494
# 19  Downtown Toronto  43.662301 -79.389494

# %% [markdown]
# ## Methodology

# %% [markdown]
# In this project we are going to implement two selection process and ensemble them together to deliver a result
#
# The first process is to find out how many Chinese restaurants in each neighborhood and the distance of each neighborhood to Toronto city centre (Yonge-Dundas Square). we find the neighborhood(s) that will few Chinese restaurants but with moderate distance
#
# The second process is to find out the distance of each restaurant to Toronto centre(Yonge-Dundas Square), grouped by neighborhood ,find the mean value of the distance to Toronto centre within each neighborhood.
#
# Finally find the intersection of the two results

# %% [markdown]
# ## Analysis

# %% [markdown]
# let us perform some basic data analysis techniques to explore the data, first we are going to observe the number of Chinese restaurants in each Neighborhood.

# %%
grouped_rest_by_neigh=restaurants_in_neighborhood.groupby(by="Neighborhood").count().sort_values(by="id",ascending=False)
grouped_rest_by_neigh.reset_index(inplace=True)
grouped_rest_by_neigh[["Neighborhood","id"]]
# Out:
#                                          Neighborhood  id
# 0                                  Central Bay Street  50
# 1                      University of Toronto, Harbord  50
# 2         Queen's Park, Ontario Provincial Government  50
# 3                            Richmond, Adelaide, King  49
# 4           Kensington Market, Chinatown, Grange Park  49
# 5              First Canadian Place, Underground city  49
# 6            Toronto Dominion Centre, Design Exchange  49
# 7                            Garden District, Ryerson  47
# 8                                      St. James Town  46
# 9                      Commerce Court, Victoria Hotel  46
# 10                        Willowdale, Willowdale East  45
# 11                                          Agincourt  39
# 12                               Church and Wellesley  38
# 13  Milliken, Agincourt North, Steeles East, L'Amo...  33
# 14                                     Stn A PO Boxes  31
# 15  Harbourfront East, Union Station, Toronto Islands  26
# 16                                        Berczy Park  21
# 17                The Annex, North Midtown, Yorkville  15
# 18                      Steeles West, L'Amoreaux West  13
# 19            Clarks Corners, Tam O'Shanter, Sullivan  13
# 20                                          Downsview  11
# 21                                    York Mills West  11
# 22                          Regent Park, Harbourfront  10
# 23      East Toronto, Broadview North (Old East York)   9
# 24                       Fairview, Henry Farm, Oriole   9
# 25                                           Christie   8
# 26                        St. James Town, Cabbagetown   8
# 27        Kennedy Park, Ionview, East Birchmount Park   8
# 28       Brockton, Parkdale Village, Exhibition Place   7
# 29                                 Humewood-Cedarvale   6
# 30  Summerhill West, Rathnelly, South Hill, Forest...   6
# 31              Canada Post Gateway Processing Centre   6
# 32                           Little Portugal, Trinity   6
# 33                                   Davisville North   5
# 34                                  Wexford, Maryvale   5
# 35                      High Park, The Junction South   5
# 36                                    Studio District   5
# 37                                        The Beaches   5
# 38                       The Danforth West, Riverdale   5
# 39                                   Thorncliffe Park   5
# 40                                          Don Mills   5
# 41                                         Davisville   4
# 42                    Golden Mile, Clairlea, Oakridge   4
# 43                            Willowdale, Newtonbrook   4
# 44                  Guildwood, Morningside, West Hill   4
# 45  CN Tower, King and Spadina, Railway Lands, Har...   4
# 46                        Moore Park, Summerhill East   4
# 47                    Northwood Park, York University   4
# 48                             Parkdale, Roncesvalles   4
# 49                    Parkview Hill, Woodbine Gardens   4
# 50                                  Hillcrest Village   4
# 51                                          Glencairn   4
# 52                                          Westmount   3
# 53                                           Rosedale   3
# 54   Del Ray, Mount Dennis, Keelsdale and Silverthorn   3
# 55  South Steeles, Silverstone, Humbergate, Jamest...   3
# 56                                 Runnymede, Swansea   3
# 57  Dorset Park, Wexford Heights, Scarborough Town...   3
# 58                                          Cedarbrae   3
# 59                 North Toronto West,  Lawrence Park   3
# 60           North Park, Maple Leaf Park, Upwood Park   3
# 61  Mimico NW, The Queensway West, South of Bloor,...   2
# 62                                   Woodbine Heights   2
# 63                        Willowdale, Willowdale West   2
# 64                     India Bazaar, The Beaches West   2
# 65                                             Weston   2
# 66                   Lawrence Manor, Lawrence Heights   2
# 67                  Bedford Park, Lawrence Manor East   2
# 68                                            Leaside   2
# 69    Forest Hill North & West, Forest Hill Road Park   2
# 70                       Dufferin, Dovercourt Village   2
# 71    Cliffside, Cliffcrest, Scarborough Village West   1
# 72                                             Woburn   1
# 73                                          Parkwoods   1
# 74    Bathurst Manor, Wilson Heights, Downsview North   1
# 75                      Runnymede, The Junction North   1
# 76  Kingsview Village, St. Phillips, Martin Grove ...   1
# 77                                Scarborough Village   1
# 78  West Deane Park, Princess Gardens, Martin Grov...   1
# 79                                     Malvern, Rouge   1
# 80                                    Bayview Village   1
# 81                                Caledonia-Fairbanks   1
# 82                                      Lawrence Park   1
# 83      The Kingsway, Montgomery Road, Old Mill North   1
# 84                                           Roselawn   1
# 85                             Alderwood, Long Branch   1
# 86  Eringate, Bloordale Gardens, Old Burnhamthorpe...   1
# 87             Rouge Hill, Port Union, Highland Creek   1

# %% [markdown]
# We can observe that the top 5 neighborhoods are located in Toronto downtown area and near Chinatown and University of Toronto

# %%
distance_to_neigh=[]
for i in grouped_rest_by_neigh["Neighborhood"].tolist():
    dist=df_valid[df_valid["Neighborhood"]==i].iloc[0,7]
    distance_to_neigh.append(dist)
distance_to_neigh=distance_to_neigh[:88]
grouped_rest_by_neigh["distance to neighborhood"]=distance_to_neigh

# %%
grouped_rest_by_neigh["distance to neighborhood/KM"]=grouped_rest_by_neigh["distance to neighborhood"]/1000
grouped_rest_by_neigh.drop(columns=["distance to neighborhood"],inplace=True)

# %%
grouped_rest_by_neigh[["Neighborhood","id","distance to neighborhood/KM"]]
# Out:
#                                          Neighborhood  id  \
# 0                                  Central Bay Street  50
# 1                      University of Toronto, Harbord  50
# 2         Queen's Park, Ontario Provincial Government  50
# 3                            Richmond, Adelaide, King  49
# 4           Kensington Market, Chinatown, Grange Park  49
# 5              First Canadian Place, Underground city  49
# 6            Toronto Dominion Centre, Design Exchange  49
# 7                            Garden District, Ryerson  47
# 8                                      St. James Town  46
# 9                      Commerce Court, Victoria Hotel  46
# 10                        Willowdale, Willowdale East  45
# 11                                          Agincourt  39
# 12                               Church and Wellesley  38
# 13  Milliken, Agincourt North, Steeles East, L'Amo...  33
# 14                                     Stn A PO Boxes  31
# 15  Harbourfront East, Union Station, Toronto Islands  26
# 16                                        Berczy Park  21
# 17                The Annex, North Midtown, Yorkville  15
# 18                      Steeles West, L'Amoreaux West  13
# 19            Clarks Corners, Tam O'Shanter, Sullivan  13
# 20                                          Downsview  11
# 21                                    York Mills West  11
# 22                          Regent Park, Harbourfront  10
# 23      East Toronto, Broadview North (Old East York)   9
# 24                       Fairview, Henry Farm, Oriole   9
# 25                                           Christie   8
# 26                        St. James Town, Cabbagetown   8
# 27        Kennedy Park, Ionview, East Birchmount Park   8
# 28       Brockton, Parkdale Village, Exhibition Place   7
# 29                                 Humewood-Cedarvale   6
# 30  Summerhill West, Rathnelly, South Hill, Forest...   6
# 31              Canada Post Gateway Processing Centre   6
# 32                           Little Portugal, Trinity   6
# 33                                   Davisville North   5
# 34                                  Wexford, Maryvale   5
# 35                      High Park, The Junction South   5
# 36                                    Studio District   5
# 37                                        The Beaches   5
# 38                       The Danforth West, Riverdale   5
# 39                                   Thorncliffe Park   5
# 40                                          Don Mills   5
# 41                                         Davisville   4
# 42                    Golden Mile, Clairlea, Oakridge   4
# 43                            Willowdale, Newtonbrook   4
# 44                  Guildwood, Morningside, West Hill   4
# 45  CN Tower, King and Spadina, Railway Lands, Har...   4
# 46                        Moore Park, Summerhill East   4
# 47                    Northwood Park, York University   4
# 48                             Parkdale, Roncesvalles   4
# 49                    Parkview Hill, Woodbine Gardens   4
# 50                                  Hillcrest Village   4
# 51                                          Glencairn   4
# 52                                          Westmount   3
# 53                                           Rosedale   3
# 54   Del Ray, Mount Dennis, Keelsdale and Silverthorn   3
# 55  South Steeles, Silverstone, Humbergate, Jamest...   3
# 56                                 Runnymede, Swansea   3
# 57  Dorset Park, Wexford Heights, Scarborough Town...   3
# 58                                          Cedarbrae   3
# 59                 North Toronto West,  Lawrence Park   3
# 60           North Park, Maple Leaf Park, Upwood Park   3
# 61  Mimico NW, The Queensway West, South of Bloor,...   2
# 62                                   Woodbine Heights   2
# 63                        Willowdale, Willowdale West   2
# 64                     India Bazaar, The Beaches West   2
# 65                                             Weston   2
# 66                   Lawrence Manor, Lawrence Heights   2
# 67                  Bedford Park, Lawrence Manor East   2
# 68                                            Leaside   2
# 69    Forest Hill North & West, Forest Hill Road Park   2
# 70                       Dufferin, Dovercourt Village   2
# 71    Cliffside, Cliffcrest, Scarborough Village West   1
# 72                                             Woburn   1
# 73                                          Parkwoods   1
# 74    Bathurst Manor, Wilson Heights, Downsview North   1
# 75                      Runnymede, The Junction North   1
# 76  Kingsview Village, St. Phillips, Martin Grove ...   1
# 77                                Scarborough Village   1
# 78  West Deane Park, Princess Gardens, Martin Grov...   1
# 79                                     Malvern, Rouge   1
# 80                                    Bayview Village   1
# 81                                Caledonia-Fairbanks   1
# 82                                      Lawrence Park   1
# 83      The Kingsway, Montgomery Road, Old Mill North   1
# 84                                           Roselawn   1
# 85                             Alderwood, Long Branch   1
# 86  Eringate, Bloordale Gardens, Old Burnhamthorpe...   1
# 87             Rouge Hill, Port Union, Highland Creek   1
#
#     distance to neighborhood/KM
# 0                      0.820184
# 1                      2.383689
# 2                      1.552538
# 3                      0.471690
# 4                      1.873503
# 5                      0.831382
# 6                      1.045900
# 7                      0.827280
# 8                      1.039831
# 9                      0.971820
# 10                    18.867945
# 11                    26.571952
# 12                     1.983309
# 13                    28.309320
# 14                     1.545560
# 15                     2.043592
# 16                     1.863131
# 17                     3.981595
# 18                    24.554913
# 19                    22.477924
# 20                    16.385336
# 21                    15.987610
# 22                     2.710884
# 23                     7.372241
# 24                    20.458544
# 25                     5.172395
# 26                     2.990858
# 27                    18.497099
# 28                     5.793609
# 29                     8.246575
# 30                     5.592463
# 31                    27.084299
# 32                     4.256974
# 33                     9.510566
# 34                    18.525034
# 35                     9.482458
# 36                     5.091626
# 37                    11.178808
# 38                     5.569532
# 39                     9.221708
# 40                    15.235471
# 41                     8.154638
# 42                    14.769843
# 43                    21.861909
# 44                    28.689938
# 45                     4.113190
# 46                     5.776499
# 47                    21.882798
# 48                     8.445201
# 49                    12.063876
# 50                    24.142126
# 51                    11.442932
# 52                    18.536870
# 53                     4.239856
# 54                    12.273523
# 55                    27.423167
# 56                    11.686396
# 57                    21.002089
# 58                    25.435966
# 59                    10.220240
# 60                    15.647152
# 61                    16.417196
# 62                    10.140949
# 63                    21.745042
# 64                     8.323285
# 65                    17.775575
# 66                    14.010776
# 67                    13.424836
# 68                     9.205283
# 69                     7.647239
# 70                     7.218027
# 71                    19.556145
# 72                    26.992574
# 73                    17.156472
# 74                    17.490395
# 75                    12.411962
# 76                    20.630190
# 77                    22.229861
# 78                    19.853405
# 79                    32.910506
# 80                    21.341032
# 81                     9.882431
# 82                    11.937447
# 83                    14.296003
# 84                    10.071051
# 85                    20.280380
# 86                    22.520542
# 87                    33.329234

# %% [markdown]
# We have already finished the first method and demostrated the dataframe indicates the number of Chinese resatuant and the distance to city centre, we find that most neighborhoods with high number of Chinese restaurant are either located in Downtown Toronto or pretty far away from Toronto centre and that makes sense. These neighborhoods are out of considerations because it could be too competitive. but there are a few communities near Toronto Centre but with fewer Chinese restaurants. they are **Berczy Park, The Annex, North Midtown, Yorkville and East Toronto, Harbourfront East, Union Station, Toronto Islands, Broadview North (Old East York)**. these neighborhoods have around 20 Chinese restaurants means that Chinese food are still popular but not too competitive.

# %%
restaurants_in_neighborhood.head()
# Out:
#                          id                 name  \
# 0  4c0150f4716bc9b65b9dbb55  Spicy Chicken House
# 1  4be21e1921d5a59390ec1511       Peking Express
# 2  4bace084f964a520ca143be3       Oriental Taste
# 3  4bca992068f976b017d35f83        China Gourmet
# 4  5b3aa3ec029a55002c3f0338       Bamboo Kitchen
#
#                                           categories    referralId hasPerk  \
# 0  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1595306675   False
# 1  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1595306676   False
# 2  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1595306676   False
# 3  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1595306676   False
# 4  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1595306676   False
#
#       location.address  location.lat  location.lng  \
# 0  1277 York Mills Rd.     43.760639    -79.325671
# 1                  NaN     43.656692    -79.365126
# 2         329 Queen st     43.655304    -79.365312
# 3       235 Carlton St     43.664180    -79.368359
# 4    292 Parliament st     43.658620    -79.365881
#
#                              location.labeledLatLngs location.distance  \
# 0  [{'label': 'display', 'lat': 43.76063939666398...               881
# 1  [{'label': 'display', 'lat': 43.6566919000341,...               451
# 2  [{'label': 'display', 'lat': 43.655304, 'lng':...               394
# 3  [{'label': 'display', 'lat': 43.6641802410051,...              1267
# 4  [{'label': 'display', 'lat': 43.65862, 'lng': ...               643
#
#   location.postalCode location.cc location.city location.state  \
# 0             M3A 1Z5          CA    North York             ON
# 1                 NaN          CA           NaN            NaN
# 2                 NaN          CA       Toronto             ON
# 3             M5A 2L2          CA       Toronto             ON
# 4             M5A 3A4          CA       Toronto             ON
#
#   location.country                          location.formattedAddress  \
# 0           Canada  [1277 York Mills Rd., North York ON M3A 1Z5, C...
# 1           Canada                                           [Canada]
# 2           Canada     [329 Queen st (Parliment), Toronto ON, Canada]
# 3           Canada  [235 Carlton St (at Parliament St), Toronto ON...
# 4           Canada    [292 Parliament st, Toronto ON M5A 3A4, Canada]
#
#   location.crossStreet venuePage.id location.neighborhood  \
# 0                  NaN          NaN                   NaN
# 1                  NaN          NaN                   NaN
# 2            Parliment          NaN                   NaN
# 3     at Parliament St          NaN                   NaN
# 4                  NaN          NaN                   NaN
#
#                 Neighborhood           Borough   Latitude  Longitude
# 0                  Parkwoods        North York  43.753259 -79.329656
# 1  Regent Park, Harbourfront  Downtown Toronto  43.654260 -79.360636
# 2  Regent Park, Harbourfront  Downtown Toronto  43.654260 -79.360636
# 3  Regent Park, Harbourfront  Downtown Toronto  43.654260 -79.360636
# 4  Regent Park, Harbourfront  Downtown Toronto  43.654260 -79.360636

# %% [markdown]
# We are going to calculate the distance of each restaurants to the city centre

# %%
distance_of_restaurants=[]
rest_lat=restaurants_in_neighborhood["location.lat"].tolist()
rest_long=restaurants_in_neighborhood["location.lng"].tolist()
rest_geo_to_xy=[]
for i in range(len(rest_long)):
    x,y=lonlat_to_xy(rest_long[i],rest_lat[i])
    rest_geo_to_xy.append((x,y))
# Out:
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# ...
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)

# %%
len(rest_geo_to_xy)
# Out:
# 1012

# %%
rest_X_coord=[]
rest_Y_coord=[]
for i in range(len(geo_to_xy)):
    x=rest_geo_to_xy[i][0]
    y=rest_geo_to_xy[i][1]
    rest_X_coord.append(x)
    rest_Y_coord.append(y)

# %%
x_toronto,y_toronto=lonlat_to_xy(longitude, latitude)
rest_distance_to_centre=[]
for i in range(len(rest_geo_to_xy)):
    distance=calc_xy_distance(x_toronto, y_toronto, rest_geo_to_xy[i][0], rest_geo_to_xy[i][1])
    rest_distance_to_centre.append(distance)
# Out:
# <ipython-input-4-20aa3bfd6701>:10: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   xy = pyproj.transform(proj_latlon, proj_xy, lon, lat)

# %%
len(rest_distance_to_centre)
# Out:
# 1012

# %%
rest_distance_to_centre_km=[i/1000 for i in rest_distance_to_centre]

# %%
restaurants_in_neighborhood["distance to Toronto centre/KM"]=rest_distance_to_centre_km
restaurants_in_neighborhood.head(5)
# Out:
#                          id                 name  \
# 0  4c0150f4716bc9b65b9dbb55  Spicy Chicken House
# 1  4be21e1921d5a59390ec1511       Peking Express
# 2  4bace084f964a520ca143be3       Oriental Taste
# 3  4bca992068f976b017d35f83        China Gourmet
# 4  5b3aa3ec029a55002c3f0338       Bamboo Kitchen
#
#                                           categories    referralId hasPerk  \
# 0  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1595306675   False
# 1  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1595306676   False
# 2  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1595306676   False
# 3  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1595306676   False
# 4  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1595306676   False
#
#       location.address  location.lat  location.lng  \
# 0  1277 York Mills Rd.     43.760639    -79.325671
# 1                  NaN     43.656692    -79.365126
# 2         329 Queen st     43.655304    -79.365312
# 3       235 Carlton St     43.664180    -79.368359
# 4    292 Parliament st     43.658620    -79.365881
#
#                              location.labeledLatLngs location.distance  \
# 0  [{'label': 'display', 'lat': 43.76063939666398...               881
# 1  [{'label': 'display', 'lat': 43.6566919000341,...               451
# 2  [{'label': 'display', 'lat': 43.655304, 'lng':...               394
# 3  [{'label': 'display', 'lat': 43.6641802410051,...              1267
# 4  [{'label': 'display', 'lat': 43.65862, 'lng': ...               643
#
#   location.postalCode location.cc location.city location.state  \
# 0             M3A 1Z5          CA    North York             ON
# 1                 NaN          CA           NaN            NaN
# 2                 NaN          CA       Toronto             ON
# 3             M5A 2L2          CA       Toronto             ON
# 4             M5A 3A4          CA       Toronto             ON
#
#   location.country                          location.formattedAddress  \
# 0           Canada  [1277 York Mills Rd., North York ON M3A 1Z5, C...
# 1           Canada                                           [Canada]
# 2           Canada     [329 Queen st (Parliment), Toronto ON, Canada]
# 3           Canada  [235 Carlton St (at Parliament St), Toronto ON...
# 4           Canada    [292 Parliament st, Toronto ON M5A 3A4, Canada]
#
#   location.crossStreet venuePage.id location.neighborhood  \
# 0                  NaN          NaN                   NaN
# 1                  NaN          NaN                   NaN
# 2            Parliment          NaN                   NaN
# 3     at Parliament St          NaN                   NaN
# 4                  NaN          NaN                   NaN
#
#                 Neighborhood           Borough   Latitude  Longitude  \
# 0                  Parkwoods        North York  43.753259 -79.329656
# 1  Regent Park, Harbourfront  Downtown Toronto  43.654260 -79.360636
# 2  Regent Park, Harbourfront  Downtown Toronto  43.654260 -79.360636
# 3  Regent Park, Harbourfront  Downtown Toronto  43.654260 -79.360636
# 4  Regent Park, Harbourfront  Downtown Toronto  43.654260 -79.360636
#
#    distance to Toronto centre/KM
# 0                      18.423039
# 1                       2.245587
# 2                       2.184040
# 3                       2.491721
# 4                       2.253669

# %%
grouped_2_neighborhood=restaurants_in_neighborhood.groupby(by="Neighborhood").mean().sort_values(by="distance to Toronto centre/KM")
grouped_2_neighborhood.reset_index(inplace=True)
grouped_2_neighborhood
# Out:
#                                          Neighborhood  location.lat  \
# 0                            Garden District, Ryerson     43.655793
# 1                      Commerce Court, Victoria Hotel     43.650770
# 2                                      St. James Town     43.653109
# 3                            Richmond, Adelaide, King     43.653658
# 4            Toronto Dominion Centre, Design Exchange     43.651893
# 5              First Canadian Place, Underground city     43.651893
# 6                                      Stn A PO Boxes     43.649058
# 7                                         Berczy Park     43.647321
# 8                                  Central Bay Street     43.656292
# 9   Harbourfront East, Union Station, Toronto Islands     43.645527
# 10        Queen's Park, Ontario Provincial Government     43.658249
# 11          Kensington Market, Chinatown, Grange Park     43.654458
# 12                     University of Toronto, Harbord     43.656381
# 13                               Church and Wellesley     43.664534
# 14                        St. James Town, Cabbagetown     43.663049
# 15  CN Tower, King and Spadina, Railway Lands, Har...     43.640208
# 16                          Regent Park, Harbourfront     43.656994
# 17                The Annex, North Midtown, Yorkville     43.666104
# 18                                           Rosedale     43.675301
# 19                                           Christie     43.664717
# 20                                    Studio District     43.664349
# 21                           Little Portugal, Trinity     43.647463
# 22                        Moore Park, Summerhill East     43.686946
# 23       Brockton, Parkdale Village, Exhibition Place     43.642534
# 24  Summerhill West, Rathnelly, South Hill, Forest...     43.688400
# 25                       Dufferin, Dovercourt Village     43.663987
# 26                       The Danforth West, Riverdale     43.679641
# 27      East Toronto, Broadview North (Old East York)     43.684290
# 28    Forest Hill North & West, Forest Hill Road Park     43.700435
# 29                             Parkdale, Roncesvalles     43.656058
# 30                                 Humewood-Cedarvale     43.693826
# 31                                         Davisville     43.705922
# 32                     India Bazaar, The Beaches West     43.670510
# 33                                           Roselawn     43.703347
# 34                      High Park, The Junction South     43.660054
# 35                                   Davisville North     43.708095
# 36                                   Thorncliffe Park     43.701269
# 37                                            Leaside     43.708326
# 38                 North Toronto West,  Lawrence Park     43.710918
# 39                                   Woodbine Heights     43.695040
# 40                                Caledonia-Fairbanks     43.697142
# 41                                        The Beaches     43.675179
# 42                                 Runnymede, Swansea     43.652639
# 43                                          Glencairn     43.710210
# 44                                      Lawrence Park     43.726953
# 45   Del Ray, Mount Dennis, Keelsdale and Silverthorn     43.686024
# 46                      Runnymede, The Junction North     43.668005
# 47                  Bedford Park, Lawrence Manor East     43.728266
# 48                    Parkview Hill, Woodbine Gardens     43.708315
# 49                                          Don Mills     43.736299
# 50                   Lawrence Manor, Lawrence Heights     43.721790
# 51      The Kingsway, Montgomery Road, Old Mill North     43.647513
# 52           North Park, Maple Leaf Park, Upwood Park     43.710771
# 53                    Golden Mile, Clairlea, Oakridge     43.712800
# 54                                    York Mills West     43.758588
# 55  Mimico NW, The Queensway West, South of Bloor,...     43.621334
# 56                                             Weston     43.704725
# 57    Bathurst Manor, Wilson Heights, Downsview North     43.755780
# 85    -79.190823  43.763573 -79.188711                      28.842161
# 86    -79.200233  43.806686 -79.194353                      31.778723
# 87    -79.172468  43.784535 -79.160497                      32.019770

# %%
grouped_count=restaurants_in_neighborhood.groupby(by="Neighborhood").count()
grouped_count.reset_index(inplace=True)
grouped_count=grouped_count[["Neighborhood","id"]]

# %%
num_of_chinese_rest=[]
for i in grouped_2_neighborhood["Neighborhood"].tolist():
    if i in grouped_count["Neighborhood"].tolist() == False:
        num=0
    else:
        num=grouped_count[grouped_count["Neighborhood"]==i].iloc[0,1]
    num_of_chinese_rest.append(num)

# %%
grouped_2_neighborhood["num of Chinese restaurant"]=num_of_chinese_rest
grouped_2_neighborhood
# Out:
#                                          Neighborhood  location.lat  \
# 0                            Garden District, Ryerson     43.655793
# 1                      Commerce Court, Victoria Hotel     43.650770
# 2                                      St. James Town     43.653109
# 3                            Richmond, Adelaide, King     43.653658
# 4            Toronto Dominion Centre, Design Exchange     43.651893
# 5              First Canadian Place, Underground city     43.651893
# 6                                      Stn A PO Boxes     43.649058
# 7                                         Berczy Park     43.647321
# 8                                  Central Bay Street     43.656292
# 9   Harbourfront East, Union Station, Toronto Islands     43.645527
# 10        Queen's Park, Ontario Provincial Government     43.658249
# 11          Kensington Market, Chinatown, Grange Park     43.654458
# 12                     University of Toronto, Harbord     43.656381
# 13                               Church and Wellesley     43.664534
# 14                        St. James Town, Cabbagetown     43.663049
# 15  CN Tower, King and Spadina, Railway Lands, Har...     43.640208
# 16                          Regent Park, Harbourfront     43.656994
# 17                The Annex, North Midtown, Yorkville     43.666104
# 18                                           Rosedale     43.675301
# 19                                           Christie     43.664717
# 20                                    Studio District     43.664349
# 21                           Little Portugal, Trinity     43.647463
# 22                        Moore Park, Summerhill East     43.686946
# 23       Brockton, Parkdale Village, Exhibition Place     43.642534
# 24  Summerhill West, Rathnelly, South Hill, Forest...     43.688400
# 25                       Dufferin, Dovercourt Village     43.663987
# 26                       The Danforth West, Riverdale     43.679641
# 27      East Toronto, Broadview North (Old East York)     43.684290
# 28    Forest Hill North & West, Forest Hill Road Park     43.700435
# 29                             Parkdale, Roncesvalles     43.656058
# 30                                 Humewood-Cedarvale     43.693826
# 31                                         Davisville     43.705922
# 32                     India Bazaar, The Beaches West     43.670510
# 33                                           Roselawn     43.703347
# 34                      High Park, The Junction South     43.660054
# 35                                   Davisville North     43.708095
# 36                                   Thorncliffe Park     43.701269
# 37                                            Leaside     43.708326
# 38                 North Toronto West,  Lawrence Park     43.710918
# 39                                   Woodbine Heights     43.695040
# 40                                Caledonia-Fairbanks     43.697142
# 41                                        The Beaches     43.675179
# 42                                 Runnymede, Swansea     43.652639
# 43                                          Glencairn     43.710210
# 44                                      Lawrence Park     43.726953
# 45   Del Ray, Mount Dennis, Keelsdale and Silverthorn     43.686024
# 46                      Runnymede, The Junction North     43.668005
# 47                  Bedford Park, Lawrence Manor East     43.728266
# 48                    Parkview Hill, Woodbine Gardens     43.708315
# 49                                          Don Mills     43.736299
# 50                   Lawrence Manor, Lawrence Heights     43.721790
# 78    -79.356696  43.803762 -79.363452                      25.010686
# 79    -79.265607  43.794200 -79.262029                      25.978306
# 80    -79.236007  43.773136 -79.239476                      26.099027
# 81    -79.214164  43.770992 -79.216917                      26.303399
# 82    -79.615007  43.636966 -79.615819                      27.073874
# 83    -79.588052  43.739416 -79.588437                      27.168986
# 84    -79.290423  43.815252 -79.284577                      27.458091
# 85    -79.190823  43.763573 -79.188711                      28.842161
# 86    -79.200233  43.806686 -79.194353                      31.778723
# 87    -79.172468  43.784535 -79.160497                      32.019770
#
#     num of Chinese restaurant
# 0                          47
# 1                          46
# 2                          46
# 3                          49
# 4                          49
# 5                          49
# 6                          31
# 7                          21
# 8                          50
# 9                          26
# 10                         50
# 11                         49
# 12                         50
# 13                         38
# 14                          8
# 15                          4
# 16                         10
# 17                         15
# 18                          3
# 19                          8
# 20                          5
# 21                          6
# 22                          4
# 23                          7
# 24                          6
# 25                          2
# 26                          5
# 27                          9
# 28                          2
# 29                          4
# 30                          6
# 31                          4
# 32                          2
# 33                          1
# 34                          5
# 35                          5
# 36                          5
# 37                          2
# 38                          3
# 39                          2
# 40                          1
# 41                          5
# 42                          3
# 43                          4
# 44                          1
# 45                          3
# 46                          1
# 47                          2
# 48                          4
# 49                          5
# 50                          2
# 51                          1
# 52                          3
# 53                          4
# 54                         11
# 55                          2
# 56                          2
# 57                          1
# 58                          3
# 59                          5
# 60                          1
# 61                          8
# 62                         11
# 63                         45
# 64                          1
# 65                          1
# 66                          1
# 67                          9
# 68                          3
# 69                          1
# 70                          1
# 71                          4
# 72                          1
# 73                          4
# 74                         13
# 75                          1
# 76                          2
# 77                         13
# 78                          4
# 79                         39
# 80                          3
# 81                          1
# 82                          6
# 83                          3
# 84                         33
# 85                          4
# 86                          1
# 87                          1

# %% [markdown]
# We have already completed the second selection process and demostrated the above dataframe. We can observe that most neighborhood near Toronto centre have many Chinese restaurant (around 50) we observe **Berczy Park, Harbourfront East, Union Station, Toronto Islands, Harbourfront,St.,Regent Park, Harbourfront, James Town, Cabbagetown,The Annex, North Midtown, Yorkville** are good place to open Chinese restauarants

# %%
from folium import plugins
from folium.plugins import HeatMap

map_toronto = folium.Map(location=[latitude, longitude], zoom_start=11)
folium.TileLayer('cartodbpositron').add_to(map_toronto) #cartodbpositron cartodbdark_matter
HeatMap(restaurants_in_neighborhood[["location.lat","location.lng"]]).add_to(map_toronto)
folium.Marker([latitude, longitude]).add_to(map_toronto)
folium.Circle([latitude, longitude], radius=1000, fill=False, color='white').add_to(map_toronto)
folium.Circle([latitude, longitude], radius=2000, fill=False, color='white').add_to(map_toronto)
folium.Circle([latitude, longitude], radius=3000, fill=False, color='white').add_to(map_toronto)
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# The heat map below shows the density of Chinese restaurants in the Toronto. It is clear that area in red represents high density, yellow and green represents median density and blue represents low density. We can see there are lots of in **downtown Toronto** and **North York Centre Station** (the centre of North York)

# %% [markdown]
# We recall the results we generated from the first selection process: **Berczy Park, The Annex, North Midtown, Yorkville and East Toronto,Harbourfront East, Union Station, Toronto Islands, Broadview North (Old East York)** as well as the results we generated by the second process: **Berczy Park, Harbourfront East, Union Station, Toronto Islands, Harbourfront,St.,Regent Park, Harbourfront, James Town, Cabbagetown,The Annex, North Midtown, Yorkville**
#
# We take the intersection of those two results: **Berczy Park,(The Annex,North Midtown,Yorkville),(Harbourfront East,Union Station, Toronto Islands).**
#
# The final result contains seven neighborhood which is still too many, we are going to deep compare these seven neighborhood and narrow it down

# %%
my_neighborhood=["Berczy Park","The Annex, North Midtown, Yorkville","Harbourfront East, Union Station, Toronto Islands"]
my_restaurant_df=pd.DataFrame(columns=grouped_2_neighborhood.columns)
for i in my_neighborhood:
    df=grouped_2_neighborhood[grouped_2_neighborhood["Neighborhood"]==i]
    my_restaurant_df=pd.concat([my_restaurant_df,df])
my_restaurant_df
# Out:
#                                          Neighborhood  location.lat  \
# 7                                         Berczy Park     43.647321
# 17                The Annex, North Midtown, Yorkville     43.666104
# 9   Harbourfront East, Union Station, Toronto Islands     43.645527
#
#     location.lng   Latitude  Longitude  distance to Toronto centre/KM  \
# 7     -79.379142  43.644771 -79.373306                       1.212020
# 17    -79.401670  43.672710 -79.405678                       2.969228
# 9     -79.383315  43.640816 -79.381752                       1.408815
#
#    num of Chinese restaurant
# 7                         21
# 17                        15
# 9                         26

# %%
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=11)
folium.Marker([latitude, longitude], popup='Toronto Centre').add_to(map_toronto)
folium.Marker([43.644771,-79.373306], popup='Berczy Park').add_to(map_toronto)
folium.Marker([43.672710,-79.405678], popup='The Annex, North Midtown, Yorkville').add_to(map_toronto)
folium.Marker([43.640816,-79.381752], popup='Harbourfront East, Union Station, Toronto Islands').add_to(map_toronto)
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# From the map as well as the data frame we observe that Harbourfront East, Union Station, Toronto Islands and Berczy Park neighborhoods have similar number of Chinese restuarants and similar distance to city centre but Berczy Park is much better because it is much near and the number is fewer than Harbourfront East, Union Station, Toronto Islands neighborhood. The Annex, North Midtown, Yorkville is much further (more than 2 times) but the it is less competitive.

# %% [markdown]
# ## Results and Discussion

# %% [markdown]
# Our analysis shows there are lots of Chinese restaurants in the city of Toronto (around one thousand not included cities in york region and peel region). However, most of them are located in downtown. To meet our criterias, we have find a neighborhood in Toronto downtown or somewhere near downtown. After ensembled two selection method we have three neighborhoods: **Berczy Park,(The Annex,North Midtown,Yorkville),(Harbourfront East,Union Station, Toronto Islands)**. But we want to narrow down the result. We compared the three neighborhoods and labelled them on the map and we finally selected The Annex,North Midtown,Yorkville neighborhood because it is pretty near Toronto centre (3km) and market is not as competitive as the neighborhoods it near by.
#
# The neighborhood we found is the most optimal based on our selection criteria but it doesn't imply it is the best place. Selecting a community to start business doesn't simply consider these criterias. Rent, population densities,target customers are also factors that should be considered. Take an example, Yorkville is one of the region with highest rent and expense. But these factors are not included in the project. We can only say The Annex,North Midtown,Yorkville neighborhood is the best choice based on the our requirements initially set above.

# %% [markdown]
# ## Conclusion

# %% [markdown]
# The purpose of this project is to find the best neighborhood to start business based on the number of Chinese restaurants nearby and the distance to city centre. By calculating the distance with two methods and the number of Chinese restaurants in the neighborhood and narrow down analysis, we choose The Annex,North Midtown,Yorkville neighborhood. But we have to take considerations of other factors such as rent, population densities and target customers whether it nears bus stations or subway stations.
